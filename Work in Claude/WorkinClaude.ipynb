# %% [markdown]
# operation 1

# %% [markdown]
# Create a fully functional, interactive 'Pomodoro Timer' app using React. It should have a Start/Pause button, a Reset button, and a visual countdown timer.

# %% [markdown]
# https://claude.ai/public/artifacts/3ff07097-5838-4be7-9133-1f99f0c0894e

# %% [markdown]
# operation 2

# %% [markdown]
# Create a Sales Dashboard using a chart library. Visualise this data: Q1 $10k, Q2 $15k, Q3 $12k, Q4 $22k. Use a bar chart and make it colorful.

# %% [markdown]
# https://claude.ai/public/artifacts/db8ded76-8b19-43c9-96cc-a64c831d6adc

# %% [markdown]
# operation 3

# %% [markdown]
# Generate a scalable vector graphic (SVG) of a modern, geometric logo for a tech startup called 'Nebula'. It should use purple and blue gradients.

# %% [markdown]
# https://claude.ai/public/artifacts/98130d9d-4cf0-4a88-8106-794549bab7bb

# %% [markdown]
# operation 4

# %% [markdown]
# Create a Mermaid diagram showing the flowchart of a 'User Login Process'. Include steps for: Enter Creds -> Validate -> Success/Fail -> 2FA -> Dashboard.

# %% [markdown]
# flowchart TD
#     Start([Start Login]) --> EnterCreds[Enter Credentials]
#     EnterCreds --> Validate{Validate Credentials}
#     Validate -->|Invalid| FailCreds[Show Error Message]
#     FailCreds --> EnterCreds
#     Validate -->|Valid| TwoFA[Enter 2FA Code]
#     TwoFA --> ValidateTwoFA{Validate 2FA}
#     ValidateTwoFA -->|Invalid| Fail2FA[Show 2FA Error]
#     Fail2FA --> TwoFA
#     ValidateTwoFA -->|Valid| Success[Login Successful]
#     Success --> Dashboard([Redirect to Dashboard])
#
#     style Start fill:#e1f5e1
#     style Dashboard fill:#e1f5e1
#     style FailCreds fill:#ffe1e1
#     style Fail2FA fill:#ffe1e1
#     style Success fill:#e1f0ff

# %% [markdown]
# operation 5

# %% [markdown]
# Code a playable 'Snake Game' in a single HTML file using JavaScript. It should be playable with arrow keys directly in the preview window.

# %% [markdown]
# https://claude.ai/public/artifacts/a2f77587-ab4d-4fe6-8d72-a88305bcc72d

# %% [markdown]
# operation 6

# %% [markdown]
# Draft a professional 'Project Proposal' for an AI-powered Coffee Machine. Use Markdown formatting with headers for Executive Summary, Features, Budget, and Timeline.

# %% [markdown]
# https://claude.ai/public/artifacts/71311f60-90da-4db4-a02d-17c99cc4470d

# %% [markdown]
# operation 7

# %% [markdown]
# Build an interactive 'Mortgage Calculator' component. Inputs: Loan Amount, Interest Rate, Years. Output: Monthly Payment. It must update in real-time.

# %% [markdown]
# https://claude.ai/share/2e5d2987-7016-443c-979b-b866787c2bbd

# %% [markdown]
# operation 8

# %% [markdown]
# Create a 'Spanish Vocabulary Flashcard' app. It should flip when clicked. Include 5 words: Apple, House, Dog, Car, Book.

# %% [markdown]
# https://claude.ai/public/artifacts/a9ad8618-b72a-48c9-b0e3-e755031f7740

# %% [markdown]
# operation 9

# %% [markdown]
# Take this text and convert it into a structured JSON object for a database: 'John Doe, 25, Engineer; Jane Smith, 30, Designer; Bob Brown, 45, Manager'

# %% [markdown]
# {
#   "employees": [
#     {
#       "name": "John Doe",
#       "age": 25,
#       "occupation": "Engineer"
#     },
#     {
#       "name": "Jane Smith",
#       "age": 30,
#       "occupation": "Designer"
#     },
#     {
#       "name": "Bob Brown",
#       "age": 45,
#       "occupation": "Manager"
#     }
#   ]
# }

# %% [markdown]
# operation 10

# %% [markdown]
# Create a CSS-only 'Mood Board' layout showing a colour palette for a 'Summer Beach' theme. Display 5 distinct hex codes with visual swatches.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Summer Beach Mood Board</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
#             min-height: 100vh;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             padding: 20px;
#         }
#
#         .mood-board {
#             background: white;
#             border-radius: 20px;
#             box-shadow: 0 20px 60px rgba(0, 0, 0, 0.15);
#             padding: 50px;
#             max-width: 900px;
#             width: 100%;
#         }
#
#         .header {
#             text-align: center;
#             margin-bottom: 50px;
#         }
#
#         .header h1 {
#             font-size: 3em;
#             color: #2c3e50;
#             margin-bottom: 10px;
#             font-weight: 300;
#             letter-spacing: 2px;
#         }
#
#         .header p {
#             color: #7f8c8d;
#             font-size: 1.1em;
#             font-style: italic;
#         }
#
#         .palette {
#             display: grid;
#             grid-template-columns: repeat(auto-fit, minmax(150px, 1fr));
#             gap: 25px;
#             margin-top: 30px;
#         }
#
#         .color-swatch {
#             text-align: center;
#             transition: transform 0.3s ease;
#         }
#
#         .color-swatch:hover {
#             transform: translateY(-10px);
#         }
#
#         .swatch {
#             width: 100%;
#             height: 180px;
#             border-radius: 15px;
#             box-shadow: 0 8px 25px rgba(0, 0, 0, 0.1);
#             margin-bottom: 15px;
#             position: relative;
#             overflow: hidden;
#         }
#
#         .swatch::after {
#             content: '';
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: linear-gradient(135deg, rgba(255,255,255,0.3) 0%, rgba(255,255,255,0) 50%);
#         }
#
#         .color-name {
#             font-weight: 600;
#             color: #2c3e50;
#             margin-bottom: 5px;
#             font-size: 1em;
#         }
#
#         .hex-code {
#             font-family: 'Courier New', monospace;
#             color: #7f8c8d;
#             font-size: 0.95em;
#             background: #ecf0f1;
#             padding: 5px 12px;
#             border-radius: 5px;
#             display: inline-block;
#         }
#
#         /* Individual color swatches */
#         .swatch-1 { background: #87CEEB; }
#         .swatch-2 { background: #F4E8C1; }
#         .swatch-3 { background: #40E0D0; }
#         .swatch-4 { background: #FF7F50; }
#         .swatch-5 { background: #FFB347; }
#
#         /* Responsive adjustments */
#         @media (max-width: 768px) {
#             .mood-board {
#                 padding: 30px;
#             }
#
#             .header h1 {
#                 font-size: 2em;
#             }
#
#             .palette {
#                 grid-template-columns: repeat(auto-fit, minmax(120px, 1fr));
#                 gap: 20px;
#             }
#
#             .swatch {
#                 height: 140px;
#             }
#         }
#     </style>
# </head>
# <body>
#     <div class="mood-board">
#         <div class="header">
#             <h1>Summer Beach</h1>
#             <p>A vibrant coastal color palette</p>
#         </div>
#
#         <div class="palette">
#             <div class="color-swatch">
#                 <div class="swatch swatch-1"></div>
#                 <div class="color-name">Sky Blue</div>
#                 <div class="hex-code">#87CEEB</div>
#             </div>
#
#             <div class="color-swatch">
#                 <div class="swatch swatch-2"></div>
#                 <div class="color-name">Sandy Beige</div>
#                 <div class="hex-code">#F4E8C1</div>
#             </div>
#
#             <div class="color-swatch">
#                 <div class="swatch swatch-3"></div>
#                 <div class="color-name">Ocean Turquoise</div>
#                 <div class="hex-code">#40E0D0</div>
#             </div>
#
#             <div class="color-swatch">
#                 <div class="swatch swatch-4"></div>
#                 <div class="color-name">Coral Sunset</div>
#                 <div class="hex-code">#FF7F50</div>
#             </div>
#
#             <div class="color-swatch">
#                 <div class="swatch swatch-5"></div>
#                 <div class="color-name">Tangerine Glow</div>
#                 <div class="hex-code">#FFB347</div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

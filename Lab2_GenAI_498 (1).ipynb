# %% [markdown]
# Part 1

# %% [markdown]
# 1) Do a Simple practical application using LangChain - Practical Mode only.

# %%
# !pip install -U langchain langchain-core langchain-community langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.2/490.2 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.6
#     Uninstalling langchain-core-1.2.6:
#       Successfully uninstalled langchain-core-1.2.6
#   Attempting uninstall: langchain
# ...

# %%
import os
os.environ["GROQ_API_KEY"] = "Enter your API Key"

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableSequence

llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0.3)

prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

chain = RunnableSequence(prompt, llm)

result = chain.invoke({"topic": "Agentic AI"})
print(result.content)
# Out:
# **Agentic AI: A Simple Explanation**
#
# Agentic AI refers to a type of artificial intelligence (AI) that has the ability to act independently, make decisions, and take actions on its own, similar to a human agent. The term "agent" comes from the field of artificial intelligence, where an agent is a program that can interact with its environment and make decisions based on its goals and knowledge.
#
# **Key Characteristics of Agentic AI:**
#
# 1. **Autonomy**: Agentic AI can operate independently, without constant human supervision.
# 2. **Self-awareness**: Agentic AI has a sense of its own existence and goals.
# 3. **Goal-directed behavior**: Agentic AI can set and pursue its own goals, even if they conflict with human goals.
# 4. **Decision-making**: Agentic AI can make decisions based on its own knowledge and experience.
# 5. **Adaptability**: Agentic AI can adapt to changing situations and learn from its experiences.
#
# **Examples of Agentic AI:**
#
# ...

# %% [markdown]
# 2. Kaggle - Explore Kaggle Opensource and Download any dataset of your Own and Perform Simple Data Analysis. You can directly link the dataset link from the Kaggle to your Code. - Practical Mode only.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-36b0d265-43e0-4486-8dc1-bfe854e02f8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36b0d265-43e0-4486-8dc1-bfe854e02f8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pandas matplotlib seaborn

# %%
# !ls
# Out:
# AI_Impact_on_Jobs_2030.csv  sample_data

# %%
import pandas as pd

df = pd.read_csv("AI_Impact_on_Jobs_2030.csv")
df.head()
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %%
df.shape
# Out:
# (3000, 18)

# %%
df.columns
# Out:
# Index(['Job_Title', 'Average_Salary', 'Years_Experience', 'Education_Level',
#        'AI_Exposure_Index', 'Tech_Growth_Factor',
#        'Automation_Probability_2030', 'Risk_Category', 'Skill_1', 'Skill_2',
#        'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8',
#        'Skill_9', 'Skill_10'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job_Title                    3000 non-null   object
#  1   Average_Salary               3000 non-null   int64
#  2   Years_Experience             3000 non-null   int64
#  3   Education_Level              3000 non-null   object
#  4   AI_Exposure_Index            3000 non-null   float64
#  5   Tech_Growth_Factor           3000 non-null   float64
#  6   Automation_Probability_2030  3000 non-null   float64
#  7   Risk_Category                3000 non-null   object
#  8   Skill_1                      3000 non-null   float64
#  9   Skill_2                      3000 non-null   float64
#  10  Skill_3                      3000 non-null   float64
#  11  Skill_4                      3000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Job_Title                      0
# Average_Salary                 0
# Years_Experience               0
# Education_Level                0
# AI_Exposure_Index              0
# Tech_Growth_Factor             0
# Automation_Probability_2030    0
# Risk_Category                  0
# Skill_1                        0
# Skill_2                        0
# Skill_3                        0
# Skill_4                        0
# Skill_5                        0
# Skill_6                        0
# Skill_7                        0
# Skill_8                        0
# Skill_9                        0
# Skill_10                       0
# dtype: int64

# %%
df.describe()
# Out:
#        Average_Salary  Years_Experience  AI_Exposure_Index  \
# count     3000.000000       3000.000000        3000.000000
# mean     89372.279000         14.677667           0.501283
# std      34608.088767          8.739788           0.284004
# min      30030.000000          0.000000           0.000000
# 25%      58640.000000          7.000000           0.260000
# 50%      89318.000000         15.000000           0.500000
# 75%     119086.500000         22.000000           0.740000
# max     149798.000000         29.000000           1.000000
#
#        Tech_Growth_Factor  Automation_Probability_2030      Skill_1  \
# count         3000.000000                  3000.000000  3000.000000
# mean             0.995343                     0.501503     0.496973
# std              0.287669                     0.247881     0.287888
# min              0.500000                     0.050000     0.000000
# 25%              0.740000                     0.310000     0.240000
# ...

# %%
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt

df["Automation_Probability_2030"].plot(kind="hist", bins=10)
plt.show()

# %%
df["Risk_Category"].value_counts().plot(kind="bar")
plt.show()

# %%
df.groupby("Education_Level")["Automation_Probability_2030"].mean().plot(kind="bar")
plt.show()

# %%
plt.scatter(df["AI_Exposure_Index"], df["Automation_Probability_2030"])
plt.xlabel("AI Exposure Index")
plt.ylabel("Automation Probability 2030")
plt.show()

# %%
df.sort_values("Automation_Probability_2030", ascending=False)[["Job_Title","Automation_Probability_2030"]].head(10)
# Out:
#                 Job_Title  Automation_Probability_2030
# 2261        Retail Worker                         0.95
# 2292        Retail Worker                         0.95
# 2121  Construction Worker                         0.95
# 2933     Customer Support                         0.95
# 2138         Truck Driver                         0.95
# 2376        Retail Worker                         0.95
# 87          Retail Worker                         0.95
# 1021       Security Guard                         0.95
# 1740         Truck Driver                         0.95
# 2856       Security Guard                         0.95

# %%
plt.scatter(df["Average_Salary"], df["Automation_Probability_2030"])
plt.xlabel("Average Salary")
plt.ylabel("Automation Probability 2030")
plt.show()

# %%
import seaborn as sns

sns.heatmap(df.select_dtypes(include="number").corr(), annot=True)
plt.show()

# %% [markdown]
# Part 2

# %%
# !pip install fastai scikit-learn pandas

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["target"] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df["target"].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
from fastai.tabular.all import *

splits = RandomSplitter(valid_pct=0.2)(range_of(df))

to = TabularPandas(
    df,
    procs=[Categorify, FillMissing, Normalize],
    cont_names=iris.feature_names,
    y_names="target",
    y_block=CategoryBlock(),
    splits=splits
)

dls = to.dataloaders(bs=16)

# %%
learn = tabular_learner(dls, metrics=accuracy)
learn.fit_one_cycle(5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.166674</td>
#       <td>1.395848</td>
#       <td>0.366667</td>
#       <td>00:00</td>
# ...

# %%
sample = df.iloc[0]
learn.predict(sample)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (   sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
#  0          -0.956742          0.990247          -1.362898         -1.347693
#
#       target
#  0 -0.722542  ,
#  tensor([-0.7225]),
#  tensor([-0.7225]))

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')
